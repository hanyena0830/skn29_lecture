# %%
# # 정적페이지 크롤링
# %conda install requests beautifulsoup4 lxml

# # 동적페이지 크롤링
# %conda install selenium

# ChromeDriver 다운로드
# %conda install webdriver-manager

# # 데이터 처리
# %conda install pandas

# %conda install requests beautifulsoup4 lxml selenium pandas
# Out:
# 3 channel Terms of Service accepted
# Channels:
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup

# 1. http 요청
url = 'http://example.com/'
response = requests.get(url)

#2. html 파싱
soup = BeautifulSoup(response.text, 'lxml')

# 데이터 추출
title = soup.find('h1').text
print(title)
# Out:
# Example Domain

# %%
from bs4 import BeautifulSoup
html = """
<html>
  <head><title>샘플 페이지</title></head>
  <body>
    <h1 class="main-title">제목</h1>
    <div id="content">
      <p class="text">첫 번째 문단</p>
      <p class="text">두 번째 문단</p>
      <a href="/page1">링크1</a>
      <a href="/page2">링크2</a>
    </div>
  </body>
</html>
"""
soup = BeautifulSoup(html, 'lxml')

# %%
# 태그로 찾기
title = soup.find('h1')
print(title.text)

for p in soup.find_all('p'):
    print(p.text)

# CSS 선택자 ( select )
# class로 찾기
texts = soup.select('.text')

# id로 찾기
content = soup.select('#content')

# 복합 선택자
links = soup.select('div#content a')

# 태그명으로 찾기
soup.select('p')
# Out:
# 제목
# 첫 번째 문단
# 두 번째 문단
# [<p class="text">첫 번째 문단</p>, <p class="text">두 번째 문단</p>]

# %%
html = """
<html>
  <body>
    <a href="/page1">링크1</a>
    <a href="/page2">링크2</a>
    <img src="/image1.jpg" alt="이미지1">
    <img src="/image2.jpg" alt="이미지2">
  </body>
</html>
"""
soup = BeautifulSoup(html, 'lxml')
# 또는 soup = BeautifulSoup(html, 'html.parser')

# href 속성 가져오기
link = soup.find('a')
print(link['href'])
print(link.get('href')) # 안전한 방법

# 모든 링크 추출하기
for p in soup.select('a'):
    print(p.get('href'))
# Out:
# /page1
# /page1
# /page1
# /page2

# %%
# 실제 사이트

import requests
from bs4 import BeautifulSoup
url = 'https://books.toscrape.com/'
response = requests.get(url)
response.raise_for_status # 에러체크

soup = BeautifulSoup(response.text, 'lxml')
soup.select('article.product_pod')[0].find('h3').find('a').get('title')
soup.select('article.product_pod')[0].select_one('h3 a').get('title')
# Out:
# 'A Light in the Attic'

# %%
import requests
from bs4 import BeautifulSoup
titles, links = [], []

for pagenum in range(1,51):
    url = f'https://books.toscrape.com/catalogue/page-{pagenum}.html'
    response = requests.get(url)
    response.raise_for_status()  # 에러체크

    soup = BeautifulSoup(response.text, 'lxml')

    for li in soup.select('ol.row li '):
        # print(li.select('article.product_pod')[0].select_one('h3 a').get('title'))
        titles.append(li.select('article.product_pod')[0].select_one('h3 a').get('title'))
        links.append( 'https://books.toscrape.com/'+ li.select('article.product_pod')[0].select_one('h3 a').get('href') )

# %%
import pandas as pd
data = {
    'title' : titles,
    'links' : links
}
pd.DataFrame(data)
# Out:
#                                                  title  \
# 0                                 A Light in the Attic
# 1                                   Tipping the Velvet
# 2                                           Soumission
# 3                                        Sharp Objects
# 4                Sapiens: A Brief History of Humankind
# ..                                                 ...
# 995  Alice in Wonderland (Alice's Adventures in Won...
# 996   Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)
# 997  A Spy's Devotion (The Regency Spies of London #1)
# 998                1st to Die (Women's Murder Club #1)
# 999                 1,000 Places to See Before You Die
#
#                                                  links
# 0    https://books.toscrape.com/a-light-in-the-atti...
# 1    https://books.toscrape.com/tipping-the-velvet_...
# 2    https://books.toscrape.com/soumission_998/inde...
# 3    https://books.toscrape.com/sharp-objects_997/i...
# 4    https://books.toscrape.com/sapiens-a-brief-his...
# ..                                                 ...
# 995  https://books.toscrape.com/alice-in-wonderland...
# 996  https://books.toscrape.com/ajin-demi-human-vol...
# 997  https://books.toscrape.com/a-spys-devotion-the...
# 998  https://books.toscrape.com/1st-to-die-womens-m...
# 999  https://books.toscrape.com/1000-places-to-see-...
#
# [1000 rows x 2 columns]

# %%
import requests
from bs4 import BeautifulSoup
url = 'https://news.naver.com/section/100'

response = requests.get(url)

soup = BeautifulSoup(response.text, 'html.parser')

result = soup.select_one('div.section_article.as_headline._TEMPLATE')
for data in result.select('ul>li'):
    print(data.select_one('strong.sa_text_strong').text)
# Out:
# 해군, 천안함 46용사 16주기 추모식 거행‥국방차관 참석
# 이 대통령 "전기요금 웬만하면 유지‥절약할 수 있도록 각별히 협조해달라"
# 첫 첨단 초음속 KF-21 성공…대통령도 세일즈
# 국회 간 주한이란대사 "한국인 가장 우선 대피하도록 협조"
# [속보]이 대통령 국정 지지율 69% 취임 후 최고치…민주 46%, 국힘 18%[NBS]
# '25조 원 규모' 추경안 논의…31일 국회 제출
# 장동혁 “추경? 돈 풀어서 해결 안 돼” 이준석 “25조 현금 대신 유류세 면제해라”
# 한병도 "국민의힘에 법사위원장 내줄 생각 없어"
# 비례 청년 오디션에…국힘, ‘음주 폭행 이력’의 방송인 심사위원 임명
# 벨라루스 대통령 첫 방북…김정은, 김일성광장서 환영식 열어

# %%
# %pip install webdriver-manager
# Out:
# Requirement already satisfied: webdriver-manager in c:\Users\Playdata\AppData\Local\miniconda3\envs\base_stream\Lib\site-packages (4.0.2)
# Requirement already satisfied: requests in c:\Users\Playdata\AppData\Local\miniconda3\envs\base_stream\Lib\site-packages (from webdriver-manager) (2.32.5)
# Requirement already satisfied: python-dotenv in c:\Users\Playdata\AppData\Local\miniconda3\envs\base_stream\Lib\site-packages (from webdriver-manager) (1.2.1)
# Requirement already satisfied: packaging in c:\Users\Playdata\AppData\Local\miniconda3\envs\base_stream\Lib\site-packages (from webdriver-manager) (25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\Playdata\AppData\Local\miniconda3\envs\base_stream\Lib\site-packages (from requests->webdriver-manager) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\Playdata\AppData\Local\miniconda3\envs\base_stream\Lib\site-packages (from requests->webdriver-manager) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\Users\Playdata\AppData\Local\miniconda3\envs\base_stream\Lib\site-packages (from requests->webdriver-manager) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\Users\Playdata\AppData\Local\miniconda3\envs\base_stream\Lib\site-packages (from requests->webdriver-manager) (2026.2.25)
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

driver.get("https://example.com")

print(driver.title)

time.sleep(5)

driver.get("https://daum.net")

print(driver.title)

time.sleep(5)

driver.quit()
# Out:
# Example Domain
# Daum
